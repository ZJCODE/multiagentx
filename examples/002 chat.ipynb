# %%
import os
from dotenv import load_dotenv
from openai import OpenAI
from multiagentx import Env,Group,Agent
from multiagentx.utilities.tools import web_search

from IPython.display import Image

# %%
# load the environment variables
load_dotenv()
# create a model client
model_client = OpenAI(
    api_key=os.environ.get("OPENAI_API_KEY"),
    base_url=os.environ.get("OPENAI_BASE_URL"),
)
# create an environment
env = Env(
    description="This is a test environment",
    members=[
        Agent(name="agent1", 
              role="Mathematician", 
              description="Transfer to me if you need help with math.", 
              persona = "You are a mathematician who loves to solve math problems.",
              dify_access_token=os.environ.get("AGENT1_ACCESS_TOKEN"),
              verbose=True),

        Agent(name="agent2", 
              role="Musician", 
              description="Transfer to me if you need help with music.", 
              persona = "You are a musician who loves to play music",
              model_client=model_client,
              verbose=True),

        Agent(name="agent3", 
              role="Researcher",
              description="Transfer to me if you need help with research some specific topic.",
              persona = "You are a researcher who will always do a web search before answering your questions.",
              model_client=model_client,
              tools=[web_search],
              verbose=True),
    ]
)
# create a group of agents
g = Group(env=env,model_client=model_client,verbose=True)

Image(g.draw_relations())
# Out:
#
# [2025-02-19 16:47:56][INFO]: All agents are fully connected
#
# [2025-02-19 16:47:56][INFO]: Group initialized with ID aa3f8b66-6ea4-4fb8-a62b-8c9cfdab32c6

# %%
_ = g.chat("What can you guys as a group do?")
Image(g.draw_relations())
# Out:
#
# [2025-02-19 16:47:57][INFO]: User input (talk): What can you guys as a group do?
#
# [2025-02-19 16:47:58][INFO]: Calling Dify agent [agent1]
#
# [2025-02-19 16:47:58][INFO]: Sending request to Dify API
#
# [2025-02-19 16:48:00][INFO]: Successfully received response from Dify API
#
# [2025-02-19 16:48:00][INFO]: Agent agent1 response:
#
# As a group, we can collaborate on various projects that combine our expertise. For instance, I can help solve mathematical problems, explore theories, and provide proofs, while the musician can contribute insights on rhythm, composition, and theory in music. The researcher can assist with gathering information, conducting web searches, and analyzing data. Together, we can create interdisciplinary projects that integrate mathematics and music, or research topics that require both analytical and creative approaches.

# %%
_ = g.chat("Can you explain the concept of derivative to me?")
Image(g.draw_relations())
# Out:
#
# [2025-02-19 16:48:04][INFO]: User input (talk): Can you explain the concept of derivative to me?
#
# [2025-02-19 16:48:05][INFO]: Calling Dify agent [agent1]
#
# [2025-02-19 16:48:05][INFO]: Sending request to Dify API
#
# [2025-02-19 16:48:09][INFO]: Successfully received response from Dify API
#
# [2025-02-19 16:48:09][INFO]: Agent agent1 response:
#
# The derivative is a fundamental concept in calculus that measures how a function changes as its input changes. In simpler terms, it represents the rate of change or the slope of a function at a particular point.
#
# To understand derivatives, consider a function f(x). The derivative of f, denoted as f'(x) or df/dx, is defined as the limit of the average rate of change of the function as the interval approaches zero. Mathematically, this is expressed as:
#
# f'(x) = lim (h → 0) [(f(x + h) - f(x)) / h]
#
# This formula calculates the slope of the tangent line to the curve of the function at the point x. If the derivative at a point is positive, the function is increasing at that point; if it's negative, the function is decreasing. If the derivative is zero, the function has a horizontal tangent, indicating a potential maximum, minimum, or inflection point.
#
# Derivatives have important applications in various fields, including physics for motion analysis, economics for calculating marginal cost, and many others. They help us understand how changes in one quantity affect another.

# %%
_ = g.chat("introduction to classical music")
Image(g.draw_relations())
# Out:
#
# [2025-02-19 16:48:16][INFO]: User input (talk): introduction to classical music
#
# [2025-02-19 16:48:17][INFO]: handoff from agent1 to agent2 by using auto mode
#
# [2025-02-19 16:48:18][INFO]: Calling OpenAI agent [agent2]
#
# [2025-02-19 16:48:21][INFO]: Agent agent2 response:
#
# Classical music is a broad term that refers to a long tradition of music that has its roots in Western culture, spanning from the medieval period to the present day. It encompasses a range of styles, forms, and composers, and is characterized by its rich harmonic language and formal structures.
#
# The classical era is often associated with composers like Mozart, Beethoven, and Haydn. Their music is known for its elegance, clarity, and balance, with an emphasis on melody and harmony. The Romantic period followed, bringing more emotional expression and individualism, with composers like Chopin, Wagner, and Tchaikovsky at the forefront.
#
# Classical music is typically performed in concert halls and features ensembles such as orchestras, chamber groups, and soloists. It often includes various forms such as symphonies, concertos, sonatas, and operas, each serving unique purposes and showcasing different musical ideas.
#
# Overall, classical music has had a profound impact on many genres and continues to be studied, performed, and cherished for its artistic depth and historical significance. Whether you're new to it or have some familiarity, exploring classical music can be a deeply rewarding experience!

# %%
_ = g.chat("introduction to llm")
Image(g.draw_relations())
# Out:
#
# [2025-02-19 16:48:27][INFO]: User input (talk): introduction to llm
#
# [2025-02-19 16:48:27][INFO]: handoff from agent2 to agent3 by using auto mode
#
# [2025-02-19 16:48:28][INFO]: Calling OpenAI agent [agent3]
#
# [2025-02-19 16:48:29][INFO]: Tool Call [web_search] with arguments: {'query': 'introduction to large language models', 'timelimit': 'm', 'max_results': 10} by agent3
#
# [2025-02-19 16:48:51][INFO]: Tool Call [web_search] Result Received
#
# [2025-02-19 16:48:51][INFO]: All Tool Calls Completed, Process All Tool Call Results
#
# [2025-02-19 16:48:54][INFO]: Agent agent3 response:
#
# Large Language Models (LLMs) are advanced artificial intelligence systems designed to understand, generate, and process human language at scale. They utilize deep learning techniques and are trained on vast amounts of text data, allowing them to learn patterns, relationships, and structures within language.
#
# LLMs have gained significant attention due to their impressive capabilities in natural language processing (NLP) tasks, such as text generation, machine translation, and summarization. Notable examples of LLMs include OpenAI's GPT-3 and Google's BERT, which have transformed various applications by producing human-like text and enhancing user interactions.
#
# The development of LLMs has revolutionized the field of AI, making them invaluable tools in numerous domains, including customer service, content creation, and education. Their ability to generate coherent and contextually relevant text has led to widespread adoption and ongoing research into their functionalities and implications.
#
# For more detailed information, you can explore resources like [GeeksforGeeks](https://www.geeksforgeeks.org/large-language-model-llm/) and [AIMultiple](https://research.aimultiple.com/large-language-models/).
